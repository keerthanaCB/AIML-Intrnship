# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\keert\Downloads\Student_Performance.csv")
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
num_df = df.select_dtypes(include=np.number)
num_df.head()
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
corr = num_df.corr()
corr
# Out:
#                                   Hours Studied  Previous Scores  Sleep Hours  \
# Hours Studied                          1.000000        -0.012390     0.001245
# Previous Scores                       -0.012390         1.000000     0.005944
# Sleep Hours                            0.001245         0.005944     1.000000
# Sample Question Papers Practiced       0.017463         0.007888     0.003990
# Performance Index                      0.373730         0.915189     0.048106
#
#                                   Sample Question Papers Practiced  \
# Hours Studied                                             0.017463
# Previous Scores                                           0.007888
# Sleep Hours                                               0.003990
# Sample Question Papers Practiced                          1.000000
# Performance Index                                         0.043268
#
#                                   Performance Index
# Hours Studied                              0.373730
# Previous Scores                            0.915189
# Sleep Hours                                0.048106
# Sample Question Papers Practiced           0.043268
# Performance Index                          1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr,
            annot=True,
            cmap="coolwarm",
            fmt="2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
high_corr = []
for i in range(len(corr.columns)):
    for j in range(i):
        if abs(corr.iloc[i,j]) > 0.8:
            high_corr.append((corr.columns[i],
                              corr.columns[j], corr.iloc[i, j]))

# %%
high_corr
# Out:
# [('Performance Index', 'Previous Scores', 0.9151891412264554)]

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x=num_df["Previous Scores"])
plt.title("Box plot for outliers")
plt.show()
